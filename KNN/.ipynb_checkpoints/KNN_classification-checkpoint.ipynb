# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=3,n_redundant=1,n_classes=2,random_state=999)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=999)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier()

# %%
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# 0.8766666666666667
# [[123  15]
#  [ 22 140]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       138
#            1       0.90      0.86      0.88       162
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300

# %% [markdown]
# Hyper-Parameter tuning

# %%
params = {
    'n_neighbors': [2, 3, 4, 5, 6],  # Valid parameter for KNeighborsClassifier
    'weights': ['uniform', 'distance'],  # Example of additional parameter tuning
    'metric': ['euclidean', 'manhattan']  # Example of tuning the distance metric
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(estimator=KNeighborsClassifier(),param_grid=params)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [2, 3, 4, 5, 6],
#                          'weights': ['uniform', 'distance']})

# %%
grid.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'uniform'}

# %%
grid.best_score_
# Out:
# 0.9085714285714286

# %%
y_pred1=grid.predict(X_test)

# %%
print(accuracy_score(y_pred1,y_test))
print(confusion_matrix(y_pred1,y_test))
print(classification_report(y_pred1,y_test))
# Out:
# 0.8833333333333333
# [[126  16]
#  [ 19 139]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       142
#            1       0.90      0.88      0.89       158
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300
